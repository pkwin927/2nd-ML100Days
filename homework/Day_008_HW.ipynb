# %% [markdown]
# # 常用的 DataFrame 操作
# * merge / transform
# * subset
# * groupby

# %%
# Import 需要的套件
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('C:/Users/genio/Desktop/100Days')
import EDA as eda
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
app_train = pd.read_csv("C:/Users/genio/Desktop/100Days/application_train.csv")
app_train.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %% [markdown]
# ## 作業
# 1. 請將 app_train 中的 CNT_CHILDREN 依照下列規則分為四組，並將其結果在原本的 dataframe 命名為 CNT_CHILDREN_GROUP
#     * 0 個小孩
#     * 有 1 - 2 個小孩
#     * 有 3 - 5 個小孩
#     * 有超過 5 個小孩
#
# 2. 請根據 CNT_CHILDREN_GROUP 以及 TARGET，列出各組的平均 AMT_INCOME_TOTAL，並繪製 baxplot
# 3. 請根據 CNT_CHILDREN_GROUP 以及 TARGET，對 AMT_INCOME_TOTAL 計算 [Z 轉換](https://en.wikipedia.org/wiki/Standard_score) 後的分數

# %%
#1
"""
Your code here
"""
app_train["CNT_CHILDREN_GROUP"] = pd.cut(app_train['CNT_CHILDREN'],[0,1,3,6,app_train['CNT_CHILDREN'].max()+1],right = False,labels = ['0 kids','1-2 kids','3-5 kids','5 up'])

app_train['CNT_CHILDREN_GROUP'].value_counts()
# Out:
# 0 kids      215371
# 1-2 kids     87868
# 3-5 kids      4230
# 5 up            42
# Name: CNT_CHILDREN_GROUP, dtype: int64

# %%
#2-1
"""
Your code here
"""
grouped_df = app_train.groupby(["CNT_CHILDREN_GROUP","TARGET"])['AMT_INCOME_TOTAL']
grouped_df.mean().reset_index(drop = False)
# Out:
#   CNT_CHILDREN_GROUP  TARGET  AMT_INCOME_TOTAL
# 0             0 kids       0     166747.010980
# 1             0 kids       1     160804.210548
# 2           1-2 kids       0     174590.584401
# 3           1-2 kids       1     176115.362720
# 4           3-5 kids       0     175053.742913
# 5           3-5 kids       1     160677.385714
# 6               5 up       0     139159.090909
# 7               5 up       1     180000.000000

# %%
#2-2
"""
Your code here
"""
import seaborn as sns

#sns.boxplot(x = "AMT_INCOME_TOTAL",y = ['CNT_CHILDREN_GROUP'],hue = "TARGET",data = app_train)
#plt.xlim(None)
eda.IQRScore(app_train,target = ["AMT_INCOME_TOTAL"], classification = 'CNT_CHILDREN_GROUP',label = 'TARGET',plot = True,figsize = (10,5),xlim = [0,1000000])
# Out:
#                   IQR_Score  Outliers_Counts        Q1  Q1 - 1.5IQR        Q3  \
# AMT_INCOME_TOTAL    90000.0            14035  112500.0     -22500.0  202500.0
#
#                   Q3 + 1.5IQR
# AMT_INCOME_TOTAL     337500.0

# %%
def standard(x):
    
    x['AMT_INCOME_TOTAL'] = StandardScaler().fit_transform(x['AMT_INCOME_TOTAL'].to_frame())
    
    return(x)

app_train['AMT_INCOME_TOTAL_Z_BY_CHILDREN_GRP-TARGET'] = app_train.groupby(['CNT_CHILDREN_GROUP','TARGET']).apply(standardize)['AMT_INCOME_TOTAL']

app_train[['AMT_INCOME_TOTAL','AMT_INCOME_TOTAL_Z_BY_CHILDREN_GRP-TARGET']].head()
# Out:
#    AMT_INCOME_TOTAL  AMT_INCOME_TOTAL_Z_BY_CHILDREN_GRP-TARGET
# 0          202500.0                                   0.491536
# 1          270000.0                                   0.972437
# 2           67500.0                                  -0.934708
# 3          135000.0                                  -0.298993
# 4          121500.0                                  -0.426136
