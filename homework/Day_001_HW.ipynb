# %% [markdown]
# ## 作業1：
#
# #### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# <p> 1. 你選的這組資料為何重要? </p>
# <p><ul> * 時常我們打開家中的冰箱，看著滿滿的食材卻不知道做甚麼料理，如果能透過現有食材判斷能煮什麼料理，我認為是個不錯的應用</ul></p>
# <p> 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)?
# <p><ul>* 資料提供者為一個Yummly的網站</ul></p>
# <p> 3. 蒐集而來的資料型態為何?</p>
# <p><ul> * Json檔案</ul></p>
# <p> 4. 這組資料想解決的問題如何評估?</p>
# <p><ul> * 目前問題是分類，預計會用F1 score</ul></p>

# %% [markdown]
# ## 作業2：
#
# #### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# <p>1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)</p>
# <p><ul> * 探討業績提升我認為不外乎開源或節流，我們可以分析客戶搭車的尖峰時段、路段、天氣及區域，根據不同狀況增加或減少人力，可以讓所花的每一分成本得到最大收益。我們也可以分析客群，查看不同客群特徵制定不同的行銷方式。也可以給客戶有個回饋機制，透過回饋的資料，制定不同司機的評價機制，汰換不好的司機，強化品牌形象。 </ul></p>
# <p>2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)</p>
# <p><ul> * 可能可以利用衛星定位紀錄路徑，起點終點時間等，天氣或是路況可以透過氣象局等公家機關資料，客戶回饋可以提供系統給客戶填寫，或是請司機以聊天方式提問，透過錄音以及語音辨識，將客戶回饋提取出來進行分析</ul></p>
# <p>3. 蒐集而來的資料型態為何</p>
# <p><ul> * 結構化資料，有數值型或是類別型資料。或是一些音檔，文字稿等資料</ul></p>
# <p>4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)</p>
# <p><ul> * 透過AB test，或是檢視施行措施後業績提升狀況等 </ul></p>

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y1):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum((y-y1)**2/len(y))
    
    return mse

# %%
def mean_absolute_error(y, y1):
    """
    請完成這個 Function 後往下執行
    """
    mae = sum(abs(y-y1)/len(y))
    
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 210.116
# The Mean absolute error is 12.044
